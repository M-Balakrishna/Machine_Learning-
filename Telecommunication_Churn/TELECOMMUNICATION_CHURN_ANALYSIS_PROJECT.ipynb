# %%
import pandas as pd 
import numpy as np

# %%
PATH = 'churn_dataset.csv'

# %%
df = pd.read_csv(PATH)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# checking column names
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# checking column data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# To check if there is any missing value in any column
pd.to_numeric(df["TotalCharges"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\.conda\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7332\2088736767.py in <module>
#       1 # To check if there is any missing value in any column
# ----> 2 pd.to_numeric(df["TotalCharges"])
#
# ~\.conda\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     182         coerce_numeric = errors not in ("ignore", "raise")
#     183         try:
# --> 184             values, _ = lib.maybe_convert_numeric(
#     185                 values, set(), coerce_numeric=coerce_numeric
#     186             )
#
# ...

# %%
# checking which type of missing value is there in particular column
df.loc[488,"TotalCharges"]
# Out:
# ' '

# %%
# replacing spaces with nan values
df["TotalCharges"]=df["TotalCharges"].replace(' ',np.nan)

# %%
# typecasting 
# converting TotalCharges data type object into float
df['TotalCharges'] = df['TotalCharges'].astype('float')

# %%
# checking info after converting datatype of TotalCharges column 'object' to 'float'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [raw]
# -- There is some null values in the TotalCharges feature.

# %%
# checking mean and median values for Totalcharges column
print("mean of TotalCharges:",df["TotalCharges"].mean())
print("median of TotalCharges:",df["TotalCharges"].median())
# Out:
# mean of TotalCharges: 2283.3004408418697
# median of TotalCharges: 1397.475

# %%
# filling nan values with median in TotalCharges feature
df["TotalCharges"]=df["TotalCharges"].replace(np.nan,df["TotalCharges"].median())

# %%
# checking is there any null values after replacing them with median
df["TotalCharges"].isnull().sum()
# Out:
# 0

# %%
# checking info after removing null values 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# checking is there any  null values
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [raw]
# -- There is no null values in the given Dataframe.

# %% [markdown]
# # Analysing Features-Univariate
# ##### Non Viz
# - Min
# - Max
# - Central Tendency
# - Percentiles
# - Dispersion
#
# ##### Viz
# - Plot of Dist- Distribution
# - Plot of box plot - Outlier

# %% [markdown]
# # Analysing gender feature - Univariate

# %%
# getting value_counts
df['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
# getting value_counts by normalization
df['gender'].value_counts(normalize=True)
# Out:
# Male      0.504756
# Female    0.495244
# Name: gender, dtype: float64

# %%
# count plot for sex column
df['gender'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing SeniorCitizen feature-Univariate

# %%
# Non-vizualisation statistical analysis
print("min of SeniorCitizen:",df["SeniorCitizen"].min())
print("max of SeniorCitizen:",df["SeniorCitizen"].max())
print("mean of SeniorCitizen:",df["SeniorCitizen"].mean())
print("median of SeniorCitizen:",df["SeniorCitizen"].median())
print("standard deviation of SeniorCitizen:",df["SeniorCitizen"].std())
# Out:
# min of SeniorCitizen: 0
# max of SeniorCitizen: 1
# mean of SeniorCitizen: 0.1621468124378816
# median of SeniorCitizen: 0.0
# standard deviation of SeniorCitizen: 0.36861160561002687

# %%
# plotting the distribution for SeniorCitizen column
df["SeniorCitizen"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# detecting outliers in SeniorCitizen column using box column
df["SeniorCitizen"].value_counts(normalize=True).plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [raw]
# -- There is one outlier in the SeniorCitizen feature. But it is not outlier most of the values for senior citizen having 1.

# %%
from scipy import stats 
import matplotlib.pyplot as plt

# %%
# QQ plot for SeniorCitizen column to check distribution for age column
stats.probplot(df["SeniorCitizen"],dist="norm",plot=plt)
plt.grid()

# %% [raw]
# -- Age column does not follows normal distribution.

# %% [markdown]
# # Analysing Partner feature - Univariate

# %%
# getting value_counts
df['Partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
# getting value_counts using normalization
df['Partner'].value_counts(normalize=True)
# Out:
# No     0.516967
# Yes    0.483033
# Name: Partner, dtype: float64

# %%
# count plot for partner column
df['Partner'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing Dependents feature - Univariate

# %%
# getting value_counts
df['Dependents'].value_counts()
# Out:
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64

# %%
# getting value_counts using normalization
df['Dependents'].value_counts(normalize=True)
# Out:
# No     0.700412
# Yes    0.299588
# Name: Dependents, dtype: float64

# %%
# count plot for partner column
df['Dependents'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing tenure feature-Univariate

# %%
# Non-vizualisation statistical analysis 
print("min of tenure:",df["tenure"].min())
print("max of tenure:",df["tenure"].max())
print("mean of tenure:",df["tenure"].mean())
print("median of tenure:",df["tenure"].median())
print("standard deviation of tenure:",df["tenure"].std())
# Out:
# min of tenure: 0
# max of tenure: 72
# mean of tenure: 32.37114865824223
# median of tenure: 29.0
# standard deviation of tenure: 24.55948102309423

# %%
# plotting the distribution for tenure column
df["tenure"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# detecting outliers in SeniorCitizen column using box column
df["tenure"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [markdown]
# -- There is no outliers in the tenure feature

# %%
# QQ plot for tenure column to check distribution for age column
stats.probplot(df["tenure"],dist="norm",plot=plt)
plt.grid()

# %% [raw]
# -- tenure feature does not follows normal distribution.Even though mean and median are almost near.

# %% [markdown]
# # Analysing PhoneService feature - Univariate

# %%
# getting value_counts
df['PhoneService'].value_counts()
# Out:
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64

# %%
# getting value_counts using normalization
df['PhoneService'].value_counts(normalize=True)
# Out:
# Yes    0.903166
# No     0.096834
# Name: PhoneService, dtype: float64

# %%
# count plot for PhoneService column
df['PhoneService'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing MultipleLines feature - Univariate

# %%
# getting value_counts
df['MultipleLines'].value_counts()
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %%
# getting value_counts using normalization
df['MultipleLines'].value_counts(normalize=True)
# Out:
# No                  0.481329
# Yes                 0.421837
# No phone service    0.096834
# Name: MultipleLines, dtype: float64

# %%
# count plot for PhoneService column
df['MultipleLines'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing InternetService feature- Univariate

# %%
#getting value_counts of InternetService feature
df['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
#getting value_counts of InternetService feature using normalization
df['InternetService'].value_counts(normalize= True)
# Out:
# Fiber optic    0.439585
# DSL            0.343746
# No             0.216669
# Name: InternetService, dtype: float64

# %%
# count plot for InternetService feature
df['InternetService'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing OnlineSecurity feature - Univariate

# %%
# getting value_counts for OnlineSecurity feature
df['OnlineSecurity'].value_counts()
# Out:
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64

# %%
# getting value_counts for OnlineSecurity feature using normalization
df['OnlineSecurity'].value_counts(normalize=True)
# Out:
# No                     0.496663
# Yes                    0.286668
# No internet service    0.216669
# Name: OnlineSecurity, dtype: float64

# %%
# count plot for  feature OnlineSecurity
df['OnlineSecurity'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing OnlineBackup feature -Univariate

# %%
# getting value_counts for OnlineBackup feature
df['OnlineBackup'].value_counts()
# Out:
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64

# %%
# getting value_counts for OnlineBackup feature using normalization
df['OnlineBackup'].value_counts(normalize=True)
# Out:
# No                     0.438450
# Yes                    0.344881
# No internet service    0.216669
# Name: OnlineBackup, dtype: float64

# %%
# count plot for  feature OnlineBackup
df['OnlineBackup'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing DeviceProtection feature - Univariate

# %%
# getting value_counts for DeviceProtection feature
df['DeviceProtection'].value_counts()
# Out:
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64

# %%
# getting value_counts for DeviceProtection feature using normalization
df['DeviceProtection'].value_counts(normalize=True)
# Out:
# No                     0.439443
# Yes                    0.343888
# No internet service    0.216669
# Name: DeviceProtection, dtype: float64

# %%
# count plot for  feature DeviceProtection
df['DeviceProtection'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing TechSupport feature - Univariate

# %%
# getting value_counts for TechSupport feature
df["TechSupport"].value_counts()
# Out:
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64

# %%
# getting value_counts for TechSupport feature using normalization
df["TechSupport"].value_counts(normalize=True)
# Out:
# No                     0.493114
# Yes                    0.290217
# No internet service    0.216669
# Name: TechSupport, dtype: float64

# %%
df["TechSupport"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing StreamingTV feature - Univariate

# %%
# getting value_counts for StreamingTV feature
df["StreamingTV"].value_counts()
# Out:
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: StreamingTV, dtype: int64

# %%
# getting value_counts for StreamingTV feature
df["StreamingTV"].value_counts(normalize=True)
# Out:
# No                     0.398978
# Yes                    0.384353
# No internet service    0.216669
# Name: StreamingTV, dtype: float64

# %%
# getting value_counts for StreamingTV feature
df["StreamingTV"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing StreamingMovies feature - Univariate

# %%
# getting value_counts for StreamingMovies feature
df["StreamingMovies"].value_counts()
# Out:
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64

# %%
# getting value_counts for StreamingMovies feature using normalization
df["StreamingMovies"].value_counts(normalize=True)
# Out:
# No                     0.395428
# Yes                    0.387903
# No internet service    0.216669
# Name: StreamingMovies, dtype: float64

# %%
# count plot for StreamingMovies feature
df["StreamingMovies"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing Contract feature - Univariate

# %%
# getting value_counts() for Contract column
df["Contract"].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
# getting value_counts for contract feature using normalization
df["Contract"].value_counts(normalize=True)
# Out:
# Month-to-month    0.550192
# Two year          0.240664
# One year          0.209144
# Name: Contract, dtype: float64

# %%
# plotting count plot for contract feature
df["Contract"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing PaperlessBilling feature - Univariate

# %%
# getting value_counts for PaperlessBilling 
df["PaperlessBilling"].value_counts()
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %%
# getting value_counts for PaperlessBilling 
df["PaperlessBilling"].value_counts(normalize=True)
# Out:
# Yes    0.592219
# No     0.407781
# Name: PaperlessBilling, dtype: float64

# %%
# plotting count plot for  PaperlessBilling feature
df["PaperlessBilling"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing PaymentMethod feature-Univariate

# %%
# getting valu_counts for PaymentMethod feature
df["PaymentMethod"].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
# getting valu_counts for PaymentMethod feature using normalization
df["PaymentMethod"].value_counts(normalize=True)
# Out:
# Electronic check             0.335794
# Mailed check                 0.228880
# Bank transfer (automatic)    0.219225
# Credit card (automatic)      0.216101
# Name: PaymentMethod, dtype: float64

# %%
# plotting count plot for  PaymentMethod feature
df["PaymentMethod"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analysing MonthlyCharges feature - Univariate

# %%
# Non-vizualisation statistical analysis 
print("min of MonthlyCharges:",df["MonthlyCharges"].min())
print("max of MonthlyCharges:",df["MonthlyCharges"].max())
print("mean of MonthlyCharges:",df["MonthlyCharges"].mean())
print("median of MonthlyCharges:",df["MonthlyCharges"].median())
print("standard deviation of MonthlyCharges:",df["MonthlyCharges"].std())
# Out:
# min of MonthlyCharges: 18.25
# max of MonthlyCharges: 118.75
# mean of MonthlyCharges: 64.76169246059922
# median of MonthlyCharges: 70.35
# standard deviation of MonthlyCharges: 30.09004709767854

# %%
# plotting the distribution for MonthlyCharges column
df["MonthlyCharges"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# detecting outliers in MonthlyCharges column using box column
df["MonthlyCharges"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [raw]
# -- There is no outliers in the MonthlyCharges column.

# %%
# QQ plot for SeniorCitizen column to check distribution for MonthlyCharges column
stats.probplot(df["MonthlyCharges"],dist="norm",plot=plt)
plt.grid()

# %% [raw]
# -- MonthlyCharges column does not follows normal distribution

# %% [markdown]
# # Analysing TotalCharges feature - Univariate

# %%
# # Non-vizualisation statistical analyssis 
print("min of TotalCharges:",df["TotalCharges"].min())
print("max of TotalCharges:",df["TotalCharges"].max())
print("mean of TotalCharges:",df["TotalCharges"].mean())
print("median of TotalCharges:",df["TotalCharges"].median())
print("standard deviation of TotalCharges:",df["TotalCharges"].std())
# Out:
# min of TotalCharges: 18.8
# max of TotalCharges: 8684.8
# mean of TotalCharges: 2281.9169281556187
# median of TotalCharges: 1397.475
# standard deviation of TotalCharges: 2265.2703984821865

# %%
# plotting kde plot for TotalCharges feature
df["TotalCharges"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# plotting box plot for TotalCharges feature
df["TotalCharges"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [raw]
# -- TotalCharges column does not having any outliers

# %%
# QQ plot for TotalCharges to know it follows which type of distribution
stats.probplot(df["TotalCharges"],dist="norm",plot=plt)
plt.grid()

# %% [raw]
# -- TotalCharges column does not follows normal distribution. And mean,median having difference in large number.

# %% [markdown]
# # Analysing Churn feature - Univariate

# %%
# getting value_counts for Churn feature
df["Churn"].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
# getting value_counts for Churn feature using normalization
df["Churn"].value_counts(normalize=True)
# Out:
# No     0.73463
# Yes    0.26537
# Name: Churn, dtype: float64

# %%
# plotting count plot for Churn feature
df["Churn"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
#  ## Bivariate Analysis

# %% [markdown]
# ## Analysing relationship between target variable(churn) and reamining  features.

# %% [markdown]
# ### Analysing relationship between Churn and Gender features.

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'gender']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='gender', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn')
plt.ylabel('Count')
plt.title('Churn by Gender')

# Display the plot
plt.show()

# %% [markdown]
# - There is no relationship between gender and churn features.

# %% [markdown]
# ### Analysing relationship between Churn and Seniorcitizen features

# %%
sns.boxplot(x="Churn",y="SeniorCitizen",data=df)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='SeniorCitizen'>

# %% [markdown]
# - There is no relationship between SeniorCitizen and Churn

# %% [markdown]
# ### Analysing relationship between Churn and Partner features

# %%
# plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'Partner']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='Partner', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn')
plt.ylabel('Count')
plt.title('Churn by Partner')

# Display the plot
plt.show()

# %% [markdown]
# - There is no relationship between Partner and Churn features.

# %% [markdown]
# ### Analysing relationship between churn and Dependents features

# %%
# plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'Dependents']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='Dependents', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn')
plt.ylabel('Count')
plt.title('Churn by Dependents')

# Display the plot
plt.show()

# %% [markdown]
# - There is no relationship between Dependents and Churn

# %% [markdown]
# ### Analysing relationship between Churn and tenure features.

# %%
sns.boxplot(x="Churn",y="tenure",data=df)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='tenure'>

# %% [markdown]
# - There is no relationship between tenure and Churn

# %% [markdown]
# ### Analysing relationship between churn and PhoneService features

# %%
# plotting box plot for categorical vs categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'PhoneService']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='PhoneService', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn')
plt.ylabel('Count')
plt.title('Churn by PhoneService') 

# Display the plot
plt.show()

# %% [markdown]
# - There is no realtionship between PhoneService and Churn features.

# %% [markdown]
# ### Analysing relationship between churn and MultipleLines feature

# %%
# plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'MultipleLines']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='MultipleLines', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn')
plt.ylabel('Count')
plt.title('Churn by MultipleLines')
 
# Display the plot
plt.show()

# %% [markdown]
# - There is no relationship between MultiLines and churn features.

# %% [markdown]
# ### Analysing relationship between Churn and InternetService features

# %%
# plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'InternetService']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='InternetService', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn')
plt.ylabel('Count')
plt.title('Churn by InternetService')

# Display the plot
plt.show()

# %% [markdown]
# - The type of internet service a customer has subscribed to can impact churn. Customers with slow or unreliable internet connections may be more likely to churn compared to those with high-speed and reliable connections.

# %% [markdown]
# ### Analysing relationship between Churn and OnlineSecurity features

# %%
# plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'OnlineSecurity']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='OnlineSecurity', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn')
plt.ylabel('Count')
plt.title('Churn by OnlineSecurity')

# Display the plot
plt.show()

# %% [markdown]
# - The availability of services like online security  can influence churn. Customers who encounter frequent technical issues or feel insecure about their online activities may be more likely to churn if these services are not provided.

# %% [markdown]
# ### Analysing relationship between churn and OnlineBackup features

# %%
# plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'OnlineBackup']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='OnlineBackup', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn')
plt.ylabel('Count')
plt.title('Churn by OnlineBackup')

# Display the plot
plt.show()

# %% [markdown]
# - There is no realtionship between Onlinebackup and Churn features.

# %% [markdown]
# ### Analysing relationship between churn and DeviceProtection

# %%
 # plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'DeviceProtection']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='DeviceProtection', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn')
plt.ylabel('Count')
plt.title('Churn by DeviceProtection')

# Display the plot
plt.show()

# %% [markdown]
# - There is no realtionship between DeviceProtection and churn features.

# %% [markdown]
# ### Analysing relationship between Churn and TechSupport features

# %%
 # plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'TechSupport']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='TechSupport', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn')
plt.ylabel('Count')
plt.title('Churn by TechSuport')

# Display the plot
plt.show()

# %% [markdown]
# - The availability of services like tech support can influence churn. Customers who encounter frequent technical issues or feel insecure about their online activities may be more likely to churn if these services are not provided.

# %% [markdown]
# ### Analysing relationship between Churn and StreamingTV

# %%
 # plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'StreamingTV']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='StreamingTV', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn') 
plt.ylabel('Count')
plt.title('Churn by StreamingTV')

# Display the plot 
plt.show()

# %% [markdown]
# ### Analysing relationship between churn and StreamingMovies features

# %%
 # plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'StreamingMovies']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='StreamingMovies', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn') 
plt.ylabel('Count')
plt.title('Churn by StreamingMovies')

# Display the plot 
plt.show()

# %% [markdown]
# - There is no realtionship between StreamingMovies and churn features.

# %% [markdown]
# ### Analysing relationship between churn and Contract features

# %%
 # plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'Contract']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='Contract', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn') 
plt.ylabel('Count')
plt.title('Churn by Contract')

# Display the plot 
plt.show()

# %% [markdown]
# - The type of contract a customer has can have a significant impact on churn. Customers on month-to-month contracts tend to have higher churn rates compared to those on longer-term contracts, such as one or two-year contracts. This is because customers with shorter contracts have more flexibility to switch providers.

# %% [markdown]
# ### Analysing realtionship between churn and PaperlessBilling

# %%
 # plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'PaperlessBilling']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='PaperlessBilling', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn') 
plt.ylabel('Count')
plt.title('Churn by PaperlessBilling')

# Display the plot 
plt.show()

# %% [markdown]
# - There is no realtionship between PaperlessBilling and Churn features.

# %% [markdown]
# ### Analysing realationship between churn and PaymentMethod

# %%
 # plotting box plot for cat and categorical column for analysing relationship
# Counting the occurrences of each combination
count_df = df.groupby(['Churn', 'PaymentMethod']).size().reset_index(name='count')

# Reshaping the data for stacked bar plot
stacked_df = count_df.pivot(index='Churn', columns='PaymentMethod', values='count')

# Creating the stacked bar plot
stacked_df.plot(kind='bar', stacked=True)

# Adding labels and titles
plt.xlabel('Churn') 
plt.ylabel('Count')
plt.title('Churn by PaymentMethod')

# Display the plot 
plt.show()

# %% [markdown]
# - The payment method chosen by customers can have an impact on churn. customers using automatic payments or those with  annual payments may have lower churn rates compared to customers who manually pay each month.

# %% [markdown]
# ### Analysing relationship between churn and MonthlyCharges

# %%
sns.boxplot(x="Churn",y="MonthlyCharges",data=df)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='MonthlyCharges'>

# %% [markdown]
# - Higher monthly charges can be a contributing factor to churn. Customers who perceive the service as expensive or are not satisfied with the value they receive may be more likely to churn.

# %% [markdown]
# ### Analysing relationship between churn and TotalCharges features

# %%
sns.boxplot(x="Churn",y="TotalCharges",data=df)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='TotalCharges'>

# %% [markdown]
# - Higher total charges can be a contributing factor to churn. Customers who perceive the service as expensive or are not satisfied with the value they receive may be more likely to churn.

# %% [markdown]
# # Insights

# %% [markdown]
# - Customers subscribed to specific services, such as online security, online backup, device protection, and tech support, may be more likely to churn. The telecom company should investigate the quality, availability, and value proposition of these services to improve customer retention.
# - The contract type, payment method, and paperless billing options may influence customer churn. Consider offering flexible contract options, convenient payment methods, and incentives for paperless billing to encourage customer loyalty.
# - High monthly charges and total charges may contribute to customer churn. Evaluate pricing strategies and ensure that customers perceive the value of the services they receive.
# - Demographic factors may play a role in churn. Tailor marketing campaigns and customer retention strategies based on gender, age range, and family status.

# %% [markdown]
# # Conclusions

# %% [markdown]
# - The analysis suggests that improving the quality and value of certain services, providing flexible contract options, optimizing pricing strategies, and implementing targeted retention efforts based on demographic factors can help reduce customer churn.
# - Further analysis, including predictive modeling, can provide more insights into the relative importance of different variables and help identify customers at risk of churn in advance.
# - Continuous monitoring of churn rates, service usage, and customer feedback is crucial to iteratively improve customer retention strategies.

# %% [markdown]
# # Recommandations

# %% [markdown]
# - Conduct customer surveys or interviews to gain qualitative insights into the reasons behind churn and gather feedback on service quality and customer experience.
# - Implement proactive customer retention measures, such as personalized offers, loyalty programs, or customer service enhancements, for customers identified as high-risk for churn.
# - Regularly review and update service offerings to align with customer needs and preferences, considering market trends and competitors.
# - Invest in improving customer support channels, ensuring prompt and effective resolutions to customer issues and concerns.
# - Develop data-driven churn prediction models to identify at-risk customers and implement targeted interventions to reduce churn.

# %% [markdown]
# ## Data preperation and Model Building

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# # Data Preperation

# %% [markdown]
# ## a)Identifying the inputs(X) and output(y)

# %%
X = df[['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges']]
y = df['Churn']

# %%
X.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
y.head()
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# Name: Churn, dtype: object

# %% [markdown]
# ##  Identify the type of ML Task
# - Alogirthm - Supervised
# - Task - Accuracy

# %% [markdown]
# ## split the data into train_test data
# - Here I'm splitting the data into 75:25 ratio.

# %%
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=100) 
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (5282, 19) (5282,)
# (1761, 19) (1761,)

# %% [markdown]
# ## separating Numerical and categorical columns

# %%
X_train.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 6630    Male              1      No         No      16          Yes
# 7013  Female              0      No         No      40          Yes
# 2224    Male              1     Yes         No      17          Yes
# 6580  Female              0     Yes        Yes      49          Yes
# 1501    Male              0      No         No      13          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 6630            No     Fiber optic                   No                   No
# 7013           Yes     Fiber optic                   No                  Yes
# 2224            No     Fiber optic                   No                  Yes
# 6580            No             DSL                   No                  Yes
# 1501            No              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
X_train.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# dtype: object

# %%
# categorical coulmns
X_train_cat = X_train.select_dtypes(include=['object'])

X_train_cat.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 6630    Male      No         No          Yes            No     Fiber optic
# 7013  Female      No         No          Yes           Yes     Fiber optic
# 2224    Male     Yes         No          Yes            No     Fiber optic
# 6580  Female     Yes        Yes          Yes            No             DSL
# 1501    Male      No         No          Yes            No              No
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 6630                   No                   No                   No
# 7013                   No                  Yes                  Yes
# 2224                   No                  Yes                   No
# 6580                   No                  Yes                  Yes
# 1501  No internet service  No internet service  No internet service
#
#               TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
# Numerical columns
X_train_num = X_train.select_dtypes(include=['int64', 'float64'])

X_train_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 6630              1      16           78.75       1218.25
# 7013              0      40           93.40       3756.40
# 2224              1      17           76.45       1233.40
# 6580              0      49           78.00       3824.20
# 1501              0      13           19.95        243.65

# %% [markdown]
# ## Scaling the Numerical columns

# %%
X_train_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 6630              1      16           78.75       1218.25
# 7013              0      40           93.40       3756.40
# 2224              1      17           76.45       1233.40
# 6580              0      49           78.00       3824.20
# 1501              0      13           19.95        243.65

# %%
# scaling the numerical features using standardization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# column names are (annoyingly) lost after Scaling
# (i.e. the dataframe is converted to a numpy ndarray)

X_train_num_rescaled = pd.DataFrame(scaler.fit_transform(X_train_num), 
                                    columns = X_train_num.columns, 
                                    index = X_train_num.index)

X_train_num_rescaled.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 6630       2.289869 -0.669552        0.471732     -0.471643
# 7013      -0.436706  0.305416        0.957819      0.649818
# 2224       2.289869 -0.628928        0.395418     -0.464949
# 6580      -0.436706  0.671028        0.446847      0.679775
# 1501      -0.436706 -0.791422       -1.479251     -0.902262

# %%
# checking mean,median,standard deviation of numerical columns after rescaling
X_train_num.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    5282.000000  5282.000000     5282.000000   5282.000000
# mean        0.160167    32.481825       64.532630   2285.697709
# std         0.366795    24.618547       30.141497   2263.467586
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.062500    402.662500
# 50%         0.000000    29.000000       70.250000   1397.475000
# 75%         0.000000    56.000000       89.700000   3808.150000
# max         1.000000    72.000000      118.650000   8670.100000

# %%
print("Number of Numerical Features:", scaler.n_features_in_)
print("Mean of each column:", scaler.mean_)
print("Std of each column:", np.sqrt(scaler.var_))
# Out:
# Number of Numerical Features: 4
# Mean of each column: [1.60166604e-01 3.24818251e+01 6.45326297e+01 2.28569771e+03]
# Std of each column: [3.66760498e-01 2.46162165e+01 3.01386433e+01 2.26325331e+03]

# %% [markdown]
# ## Apply one-Hot encoding on categorical columns

# %%
# checking value_counts for 'gender' column using normaization
X_train_cat['gender'].value_counts(normalize=True)
# Out:
# Male      0.500947
# Female    0.499053
# Name: gender, dtype: float64

# %%
# checking value_counts for 'Partner' column using normaization
X_train_cat['Partner'].value_counts(normalize=True)
# Out:
# No     0.522151
# Yes    0.477849
# Name: Partner, dtype: float64

# %%
# checking value_counts for 'Dependents' column using normaization
X_train_cat['Dependents'].value_counts(normalize=True)
# Out:
# No     0.695759
# Yes    0.304241
# Name: Dependents, dtype: float64

# %%
# checking value_counts for 'PhoneService' column using normaization
X_train_cat['PhoneService'].value_counts(normalize=True)
# Out:
# Yes    0.903824
# No     0.096176
# Name: PhoneService, dtype: float64

# %%
# checking value_counts for 'MultipleLines' column using normaization
X_train_cat['MultipleLines'].value_counts(normalize=True)
# Out:
# No                  0.485612
# Yes                 0.418213
# No phone service    0.096176
# Name: MultipleLines, dtype: float64

# %%
# checking value_counts for 'InternetService' column using normaization
X_train_cat['InternetService'].value_counts(normalize=True)
# Out:
# Fiber optic    0.434495
# DSL            0.343052
# No             0.222454
# Name: InternetService, dtype: float64

# %%
# checking value_counts for 'OnlineSecurity' column using normaization
X_train_cat['OnlineSecurity'].value_counts(normalize=True)
# Out:
# No                     0.489587
# Yes                    0.287959
# No internet service    0.222454
# Name: OnlineSecurity, dtype: float64

# %%
# checking value_counts for 'OnlineBackup' column using normaization
X_train_cat['OnlineBackup'].value_counts(normalize=True)
# Out:
# No                     0.430708
# Yes                    0.346838
# No internet service    0.222454
# Name: OnlineBackup, dtype: float64

# %%
# checking value_counts for 'DeviceProtection' column using normaization
X_train_cat['DeviceProtection'].value_counts(normalize=True)
# Out:
# No                     0.432601
# Yes                    0.344945
# No internet service    0.222454
# Name: DeviceProtection, dtype: float64

# %%
# checking value_counts for 'TechSupport' column using normaization
X_train_cat['TechSupport'].value_counts(normalize=True)
# Out:
# No                     0.485233
# Yes                    0.292314
# No internet service    0.222454
# Name: TechSupport, dtype: float64

# %%
# checking value_counts for 'StreamingTV' column using normaization
X_train_cat['StreamingTV'].value_counts(normalize=True)
# Out:
# No                     0.393033
# Yes                    0.384513
# No internet service    0.222454
# Name: StreamingTV, dtype: float64

# %%
# checking value_counts for 'StreamingMovies' column using normaization
X_train_cat['StreamingMovies'].value_counts(normalize=True)
# Out:
# Yes                    0.389436
# No                     0.388111
# No internet service    0.222454
# Name: StreamingMovies, dtype: float64

# %%
# checking value_counts for 'Contract' column using normaization
X_train_cat['Contract'].value_counts(normalize=True)
# Out:
# Month-to-month    0.542976
# Two year          0.246119
# One year          0.210905
# Name: Contract, dtype: float64

# %%
# checking value_counts for 'PaperlessBilling' column using normaization
X_train_cat['PaperlessBilling'].value_counts(normalize=True)
# Out:
# Yes    0.593147
# No     0.406853
# Name: PaperlessBilling, dtype: float64

# %%
# checking value_counts for 'PaymentMethod' column using normaization
X_train_cat['PaymentMethod'].value_counts(normalize=True)
# Out:
# Electronic check             0.334154
# Mailed check                 0.229648
# Bank transfer (automatic)    0.219614
# Credit card (automatic)      0.216585
# Name: PaymentMethod, dtype: float64

# %% [markdown]
# ## splitting categorical columns into nominal and ordinal

# %%
## Nominal categorical columns
X_train_cat_Nominal = X_train_cat[['gender','Partner','Dependents',
       'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'PaperlessBilling',
      'PaymentMethod']]
X_train_cat_Nominal.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 6630    Male      No         No          Yes            No     Fiber optic
# 7013  Female      No         No          Yes           Yes     Fiber optic
# 2224    Male     Yes         No          Yes            No     Fiber optic
# 6580  Female     Yes        Yes          Yes            No             DSL
# 1501    Male      No         No          Yes            No              No
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 6630                   No                   No                   No
# 7013                   No                  Yes                  Yes
# 2224                   No                  Yes                   No
# 6580                   No                  Yes                  Yes
# 1501  No internet service  No internet service  No internet service
#
#               TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
## ordinal catogorical coumns
X_train_cat_Ordinal = X_train_cat["Contract"]
X_train_cat_Ordinal
# Out:
# 6630    Month-to-month
# 7013    Month-to-month
# 2224    Month-to-month
# 6580          One year
# 1501          Two year
#              ...
# 79            One year
# 3927    Month-to-month
# 5955          Two year
# 6936    Month-to-month
# 5640    Month-to-month
# Name: Contract, Length: 5282, dtype: object

# %%
X_train_cat_Nominal.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 6630    Male      No         No          Yes            No     Fiber optic
# 7013  Female      No         No          Yes           Yes     Fiber optic
# 2224    Male     Yes         No          Yes            No     Fiber optic
# 6580  Female     Yes        Yes          Yes            No             DSL
# 1501    Male      No         No          Yes            No              No
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 6630                   No                   No                   No
# 7013                   No                  Yes                  Yes
# 2224                   No                  Yes                   No
# 6580                   No                  Yes                  Yes
# 1501  No internet service  No internet service  No internet service
#
#               TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
# OneHotEncoding the categorical features

from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

# column names are (annoyingly) lost after OneHotEncoding
# (i.e. the dataframe is converted to a numpy ndarray)
X_train_cat_OneEnc = pd.DataFrame(encoder.fit_transform(X_train_cat_Nominal), 
                               columns=encoder.get_feature_names_out(X_train_cat_Nominal.columns), 
                               index = X_train_cat_Nominal.index)

X_train_cat_OneEnc.head()
# Out:
# C:\Users\admin\.conda\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 6630          1.0          0.0             0.0               1.0
# 7013          0.0          0.0             0.0               1.0
# 2224          1.0          1.0             0.0               1.0
# 6580          0.0          1.0             1.0               1.0
# 1501          1.0          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 6630                             0.0                0.0
# 7013                             0.0                1.0
# 2224                             0.0                0.0
# 6580                             0.0                0.0
# ...

# %%
X_train_cat_LabelEnc = pd.DataFrame(index=X_train_cat_Ordinal.index)

X_train_cat_LabelEnc.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [6630, 7013, 2224, 6580, 1501]

# %%
cut_encoder = {'Month-to-month' : 1, 'One year' : 2, 'Two year' : 3}

X_train_cat_LabelEnc['Contract'] = X_train_cat['Contract'].apply(lambda x : cut_encoder[x])

X_train_cat_LabelEnc.head()
# Out:
#       Contract
# 6630         1
# 7013         1
# 2224         1
# 6580         2
# 1501         3

# %% [markdown]
# ### Concatinating the Nominal Categorical Features and  Ordinal categorical Features:

# %%
X_train_rescaled_cat = pd.concat([X_train_cat_OneEnc,X_train_cat_LabelEnc], axis=1)

X_train_rescaled_cat.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 6630          1.0          0.0             0.0               1.0
# 7013          0.0          0.0             0.0               1.0
# 2224          1.0          1.0             0.0               1.0
# 6580          0.0          1.0             1.0               1.0
# 1501          1.0          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 6630                             0.0                0.0
# 7013                             0.0                1.0
# 2224                             0.0                0.0
# 6580                             0.0                0.0
# 1501                             0.0                0.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 6630                          1.0                 0.0
# 7013                          1.0                 0.0
# 2224                          1.0                 0.0
# ...

# %% [markdown]
# ## Concatinating the  Categorical Features and Nominal Features:

# %%
X_train_transformed = pd.concat([X_train_num_rescaled,X_train_rescaled_cat ], axis=1)

X_train_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 6630       2.289869 -0.669552        0.471732     -0.471643          1.0
# 7013      -0.436706  0.305416        0.957819      0.649818          0.0
# 2224       2.289869 -0.628928        0.395418     -0.464949          1.0
# 6580      -0.436706  0.671028        0.446847      0.679775          0.0
# 1501      -0.436706 -0.791422       -1.479251     -0.902262          1.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 6630          0.0             0.0               1.0
# 7013          0.0             0.0               1.0
# 2224          1.0             0.0               1.0
# 6580          1.0             1.0               1.0
# 1501          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  TechSupport_Yes  \
# 6630                             0.0                0.0  ...              0.0
# ...

# %% [markdown]
# ## Preparing test Data

# %%
X_test.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4880    Male              0     Yes         No      50          Yes
# 1541    Male              0      No         No      72          Yes
# 1289    Male              0      No         No      63          Yes
# 5745  Female              0     Yes        Yes      61          Yes
# 4873  Female              0      No         No       7          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 4880            No              No  No internet service  No internet service
# 1541            No              No  No internet service  No internet service
# 1289           Yes             DSL                  Yes                  Yes
# 5745           Yes              No  No internet service  No internet service
# 4873            No              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
# checking info of the X_test data
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1761 entries, 4880 to 3368
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            1761 non-null   object
#  1   SeniorCitizen     1761 non-null   int64
#  2   Partner           1761 non-null   object
#  3   Dependents        1761 non-null   object
#  4   tenure            1761 non-null   int64
#  5   PhoneService      1761 non-null   object
#  6   MultipleLines     1761 non-null   object
#  7   InternetService   1761 non-null   object
#  8   OnlineSecurity    1761 non-null   object
#  9   OnlineBackup      1761 non-null   object
#  10  DeviceProtection  1761 non-null   object
#  11  TechSupport       1761 non-null   object
#  12  StreamingTV       1761 non-null   object
#  13  StreamingMovies   1761 non-null   object
#  14  Contract          1761 non-null   object
#  15  PaperlessBilling  1761 non-null   object
# ...

# %%
# separating categorical columns
X_test_cat = X_test.select_dtypes(include=['object'])

X_test_cat.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 4880    Male     Yes         No          Yes            No              No
# 1541    Male      No         No          Yes            No              No
# 1289    Male      No         No          Yes           Yes             DSL
# 5745  Female     Yes        Yes          Yes           Yes              No
# 4873  Female      No         No          Yes            No              No
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 4880  No internet service  No internet service  No internet service
# 1541  No internet service  No internet service  No internet service
# 1289                  Yes                  Yes                  Yes
# 5745  No internet service  No internet service  No internet service
# 4873  No internet service  No internet service  No internet service
#
#               TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
# separarting numerical columns of test data
X_test_num = X_test.select_dtypes(include=['int64', 'float64'])

X_test_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 4880              0      50           20.55       1067.65
# 1541              0      72           19.85       1434.10
# 1289              0      63           68.80       4111.35
# 5745              0      61           24.20       1445.20
# 4873              0       7           19.30        144.95

# %%
# rescaling numerical columns of test data
X_test_num_rescaled = pd.DataFrame(scaler.transform(X_test_num), 
                                   columns = X_test_num.columns, 
                                   index = X_test_num.index)

X_test_num_rescaled.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 4880      -0.436706  0.711652       -1.459343     -0.538184
# 1541      -0.436706  1.605372       -1.482569     -0.376271
# 1289      -0.436706  1.239759        0.141591      0.806650
# 5745      -0.436706  1.158512       -1.338236     -0.371367
# 4873      -0.436706 -1.035164       -1.500818     -0.945872

# %% [markdown]
# ## splitting categorical columns into nominal and ordinal

# %%
## Nominal categorical columns
X_test_cat_Nominal = X_test_cat[['gender','Partner','Dependents',
       'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'PaperlessBilling',
      'PaymentMethod']]
X_test_cat_Nominal.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 4880    Male     Yes         No          Yes            No              No
# 1541    Male      No         No          Yes            No              No
# 1289    Male      No         No          Yes           Yes             DSL
# 5745  Female     Yes        Yes          Yes           Yes              No
# 4873  Female      No         No          Yes            No              No
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 4880  No internet service  No internet service  No internet service
# 1541  No internet service  No internet service  No internet service
# 1289                  Yes                  Yes                  Yes
# 5745  No internet service  No internet service  No internet service
# 4873  No internet service  No internet service  No internet service
#
#               TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
## ordinal catogorical coumns
X_test_cat_Ordinal = X_test_cat["Contract"]
X_test_cat_Ordinal.head()
# Out:
# 4880          Two year
# 1541          Two year
# 1289          One year
# 5745          Two year
# 4873    Month-to-month
# Name: Contract, dtype: object

# %%
# OneHotEncoding the categorical features
from sklearn.preprocessing import OneHotEncoder

#encoder = OneHotEncoder(drop='first', sparse=False)

X_test_cat_OneEnc = pd.DataFrame(encoder.transform(X_test_cat_Nominal), 
                               columns=encoder.get_feature_names_out(X_test_cat_Nominal.columns), 
                               index = X_test_cat_Nominal.index)

X_test_cat_OneEnc.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 4880          1.0          1.0             0.0               1.0
# 1541          1.0          0.0             0.0               1.0
# 1289          1.0          0.0             0.0               1.0
# 5745          0.0          1.0             1.0               1.0
# 4873          0.0          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 4880                             0.0                0.0
# 1541                             0.0                0.0
# 1289                             0.0                1.0
# 5745                             0.0                1.0
# 4873                             0.0                0.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 4880                          0.0                 1.0
# 1541                          0.0                 1.0
# 1289                          0.0                 0.0
# ...

# %%
#X_test_cat_LabelEnc['Contract'] = X_test_cat['Contract'].apply(lambda x : cut_encoder[x])

#X_test_cat_LabelEnc.head()
X_test_cat_ord = X_test_cat[['Contract']]
X_test_cat_ord = pd.DataFrame(X_test_cat_ord, columns=['Contract']) 

X_test_cat_ord.head()
# Out:
#             Contract
# 4880        Two year
# 1541        Two year
# 1289        One year
# 5745        Two year
# 4873  Month-to-month

# %%
X_test_cat_LabelEnc = pd.DataFrame(index=X_test_cat_ord.index)

X_test_cat_LabelEnc.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [4880, 1541, 1289, 5745, 4873]

# %%
X_test_cat_ord.Contract.unique()
# Out:
# array(['Two year', 'One year', 'Month-to-month'], dtype=object)

# %%
X_test_cat_LabelEnc['Contract'] = X_test_cat_ord['Contract'].apply(lambda x : cut_encoder[x])

X_test_cat_LabelEnc.head()
# Out:
#       Contract
# 4880         3
# 1541         3
# 1289         2
# 5745         3
# 4873         1

# %%
X_test_cat_LabelEnc.head()
# Out:
#       Contract
# 4880         3
# 1541         3
# 1289         2
# 5745         3
# 4873         1

# %% [markdown]
# ## Concatinating the Nominal Categorical Features and Ordinal categorical Features:

# %%
X_test_rescaled_cat = pd.concat([X_test_cat_OneEnc,X_test_cat_LabelEnc], axis=1)

X_test_rescaled_cat.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 4880          1.0          1.0             0.0               1.0
# 1541          1.0          0.0             0.0               1.0
# 1289          1.0          0.0             0.0               1.0
# 5745          0.0          1.0             1.0               1.0
# 4873          0.0          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 4880                             0.0                0.0
# 1541                             0.0                0.0
# 1289                             0.0                1.0
# 5745                             0.0                1.0
# 4873                             0.0                0.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 4880                          0.0                 1.0
# 1541                          0.0                 1.0
# 1289                          0.0                 0.0
# ...

# %% [markdown]
# ## Concatinating Numerical and categorical columns

# %%
X_test_transformed = pd.concat([X_test_num_rescaled,X_test_rescaled_cat ], axis=1)

X_test_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 4880      -0.436706  0.711652       -1.459343     -0.538184          1.0
# 1541      -0.436706  1.605372       -1.482569     -0.376271          1.0
# 1289      -0.436706  1.239759        0.141591      0.806650          1.0
# 5745      -0.436706  1.158512       -1.338236     -0.371367          0.0
# 4873      -0.436706 -1.035164       -1.500818     -0.945872          0.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 4880          1.0             0.0               1.0
# 1541          0.0             0.0               1.0
# 1289          0.0             0.0               1.0
# 5745          1.0             1.0               1.0
# 4873          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  TechSupport_Yes  \
# 4880                             0.0                0.0  ...              0.0
# ...

# %% [markdown]
# ## Building a model using Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_transformed, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Prediction

# %%
y_test_pred = classifier.predict(X_test_transformed)

# %% [markdown]
# ## Evaluation

# %%
# calculate accuracy of class predictions
from sklearn import metrics

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7842135150482681

# %%
accuracy = metrics.accuracy_score(y_test, y_test_pred)
accuracy_percentage_logistics = accuracy * 100

print("%.0f"%accuracy_percentage_logistics)
# Out:
# 78

# %% [markdown]
# ## Model Building using other methods

# %% [markdown]
# ## KNN Classifier

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7552526973310619

# %%
accuracy = metrics.accuracy_score(y_test, y_test_pred)
accuracy_percentage_knn = accuracy * 100

print("%.0f"%accuracy_percentage_knn)
# Out:
# 76

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7013060760931289

# %%
accuracy = metrics.accuracy_score(y_test, y_test_pred)
accuracy_percentage_DT = accuracy * 100

print("%.0f"%accuracy_percentage_DT)
# Out:
# 70

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7791027825099376

# %%
accuracy = metrics.accuracy_score(y_test, y_test_pred)
accuracy_percentage_RF = accuracy * 100

print("%.0f"%accuracy_percentage_RF)
# Out:
# 78

# %%
from sklearn.svm import SVC
classifier = SVC()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7756956274843839

# %%
accuracy = metrics.accuracy_score(y_test, y_test_pred)
accuracy_percentage_SVC = accuracy * 100

print("%.0f"%accuracy_percentage_SVC)
# Out:
# 78

# %%
import matplotlib.pyplot as plt

# List of model names
models = ['Logistic Regression','KNN', 'Decision Tree', 'Random Forest','Support Vector Classifier']

# List of accuracy values for each model
accuracies = [accuracy_percentage_logistics, accuracy_percentage_knn, accuracy_percentage_DT, accuracy_percentage_RF,accuracy_percentage_SVC]

# Plotting the bar chart
plt.barh(models, accuracies)

# Adding labels and title
plt.ylabel('Models')
plt.xlabel('Accuracy')
plt.title('Accuracy Comparison of Different Models')


# Display the plot
plt.show()

# %% [markdown]
# ### Conclusion : Logistic Regression gives the best result,compare to other methods.
